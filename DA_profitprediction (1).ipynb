# %% [markdown]
# # **#importing all the required libraries for data manipulation and analysis**

# %%
# !pip install xlrd

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: xlrd in /usr/local/lib/python3.7/dist-packages (1.1.0)

# %%
sales_data = pd.read_excel("/content/Global Superstore_2011_to_2014.xlsx")

# %% [markdown]
# # **#converting excel to csv**

# %%
sales_data.to_csv("Global_Superstore.csv", index = None, header = True) #converting excel to csv
df = pd.DataFrame(pd.read_csv("Global_Superstore.csv"))

# %%
df.head()
# Out:
#    Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0   42433     AG-2011-2040  2011-01-01  2011-01-06  Standard Class
# 1   22253    IN-2011-47883  2011-01-01  2011-01-08  Standard Class
# 2   48883     HU-2011-1220  2011-01-01  2011-01-05    Second Class
# 3   11731  IT-2011-3647632  2011-01-01  2011-01-05    Second Class
# 4   22255    IN-2011-47883  2011-01-01  2011-01-08  Standard Class
#
#   Customer ID    Customer Name      Segment         City            State  \
# 0    TB-11280  Toby Braunhardt     Consumer  Constantine      Constantine
# 1    JH-15985      Joseph Holt     Consumer  Wagga Wagga  New South Wales
# 2      AT-735    Annie Thurman     Consumer     Budapest         Budapest
# 3    EM-14140     Eugene Moren  Home Office    Stockholm        Stockholm
# 4    JH-15985      Joseph Holt     Consumer  Wagga Wagga  New South Wales
#
#    ...        Product ID         Category Sub-Category  \
# 0  ...  OFF-TEN-10000025  Office Supplies      Storage
# 1  ...   OFF-SU-10000618  Office Supplies     Supplies
# 2  ...  OFF-TEN-10001585  Office Supplies      Storage
# 3  ...   OFF-PA-10001492  Office Supplies        Paper
# 4  ...   FUR-FU-10003447        Furniture  Furnishings
#
#                   Product Name    Sales Quantity Discount   Profit  \
# 0          Tenex Lockers, Blue  408.300        2      0.0  106.140
# 1     Acme Trimmer, High Speed  120.366        3      0.1   36.036
# 2      Tenex Box, Single Width   66.120        4      0.0   29.640
# 3  Enermax Note Cards, Premium   44.865        3      0.5  -26.055
# 4   Eldon Light Bulb, Duo Pack  113.670        5      0.1   37.770
#
#    Shipping Cost  Order Priority
# 0          35.46          Medium
# 1           9.72          Medium
# 2           8.17            High
# 3           4.82            High
# 4           4.70          Medium
#
# [5 rows x 24 columns]

# %%
df = df.sort_values(by="Order Date")

# %%
df.head()
# Out:
#    Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0   42433     AG-2011-2040  2011-01-01  2011-01-06  Standard Class
# 1   22253    IN-2011-47883  2011-01-01  2011-01-08  Standard Class
# 2   48883     HU-2011-1220  2011-01-01  2011-01-05    Second Class
# 3   11731  IT-2011-3647632  2011-01-01  2011-01-05    Second Class
# 4   22255    IN-2011-47883  2011-01-01  2011-01-08  Standard Class
#
#   Customer ID    Customer Name      Segment         City            State  \
# 0    TB-11280  Toby Braunhardt     Consumer  Constantine      Constantine
# 1    JH-15985      Joseph Holt     Consumer  Wagga Wagga  New South Wales
# 2      AT-735    Annie Thurman     Consumer     Budapest         Budapest
# 3    EM-14140     Eugene Moren  Home Office    Stockholm        Stockholm
# 4    JH-15985      Joseph Holt     Consumer  Wagga Wagga  New South Wales
#
#    ...        Product ID         Category Sub-Category  \
# 0  ...  OFF-TEN-10000025  Office Supplies      Storage
# 1  ...   OFF-SU-10000618  Office Supplies     Supplies
# 2  ...  OFF-TEN-10001585  Office Supplies      Storage
# 3  ...   OFF-PA-10001492  Office Supplies        Paper
# 4  ...   FUR-FU-10003447        Furniture  Furnishings
#
#                   Product Name    Sales Quantity Discount   Profit  \
# 0          Tenex Lockers, Blue  408.300        2      0.0  106.140
# 1     Acme Trimmer, High Speed  120.366        3      0.1   36.036
# 2      Tenex Box, Single Width   66.120        4      0.0   29.640
# 3  Enermax Note Cards, Premium   44.865        3      0.5  -26.055
# 4   Eldon Light Bulb, Duo Pack  113.670        5      0.1   37.770
#
#    Shipping Cost  Order Priority
# 0          35.46          Medium
# 1           9.72          Medium
# 2           8.17            High
# 3           4.82            High
# 4           4.70          Medium
#
# [5 rows x 24 columns]

# %%
# df.shape
print("The dataset of Global Superstore contains \nRows: {}\nColumns: {}".format(df.shape[0],df.shape[1]))
# Out:
# The dataset of Global Superstore contains
# Rows: 51290
# Columns: 24

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  object
#  3   Ship Date       51290 non-null  object
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     9994 non-null   float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
#  16  Sub-Category    51290 non-null  object
#  17  Product Name    51290 non-null  object
#  18  Sales           51290 non-null  float64
#  19  Quantity        51290 non-null  int64
#  20  Discount        51290 non-null  float64
#  21  Profit          51290 non-null  float64
#  22  Shipping Cost   51290 non-null  float64
#  23  Order Priority  51290 non-null  object
# dtypes: float64(5), int64(2), object(17)
# memory usage: 9.8+ MB

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales      Quantity      Discount  \
# count  51290.00000   9994.000000  51290.000000  51290.000000  51290.000000
# mean   25645.50000  55190.379428    246.490581      3.476545      0.142908
# std    14806.29199  32063.693350    487.565361      2.278766      0.212280
# min        1.00000   1040.000000      0.444000      1.000000      0.000000
# 25%    12823.25000  23223.000000     30.758625      2.000000      0.000000
# 50%    25645.50000  56430.500000     85.053000      3.000000      0.000000
# 75%    38467.75000  90008.000000    251.053200      5.000000      0.200000
# max    51290.00000  99301.000000  22638.480000     14.000000      0.850000
#
#              Profit  Shipping Cost
# count  51290.000000   51290.000000
# mean      28.610982      26.375818
# std      174.340972      57.296810
# min    -6599.978000       0.002000
# 25%        0.000000       2.610000
# 50%        9.240000       7.790000
# 75%       36.810000      24.450000
# max     8399.976000     933.570000

# %%
df.isnull()
# Out:
#        Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# 0       False     False       False      False      False        False
# 1       False     False       False      False      False        False
# 2       False     False       False      False      False        False
# 3       False     False       False      False      False        False
# 4       False     False       False      False      False        False
# ...       ...       ...         ...        ...        ...          ...
# 51253   False     False       False      False      False        False
# 51254   False     False       False      False      False        False
# 51255   False     False       False      False      False        False
# 51242   False     False       False      False      False        False
# 51289   False     False       False      False      False        False
#
#        Customer Name  Segment   City  State  ...  Product ID  Category  \
# 0              False    False  False  False  ...       False     False
# 1              False    False  False  False  ...       False     False
# 2              False    False  False  False  ...       False     False
# 3              False    False  False  False  ...       False     False
# 4              False    False  False  False  ...       False     False
# ...              ...      ...    ...    ...  ...         ...       ...
# 51253          False    False  False  False  ...       False     False
# 51254          False    False  False  False  ...       False     False
# 51255          False    False  False  False  ...       False     False
# 51242          False    False  False  False  ...       False     False
# 51289          False    False  False  False  ...       False     False
#
#        Sub-Category  Product Name  Sales  Quantity  Discount  Profit  \
# 0             False         False  False     False     False   False
# 1             False         False  False     False     False   False
# 2             False         False  False     False     False   False
# 3             False         False  False     False     False   False
# 4             False         False  False     False     False   False
# ...             ...           ...    ...       ...       ...     ...
# 51253         False         False  False     False     False   False
# 51254         False         False  False     False     False   False
# 51255         False         False  False     False     False   False
# 51242         False         False  False     False     False   False
# 51289         False         False  False     False     False   False
#
#        Shipping Cost  Order Priority
# 0              False           False
# 1              False           False
# 2              False           False
# 3              False           False
# 4              False           False
# ...              ...             ...
# 51253          False           False
# 51254          False           False
# 51255          False           False
# 51242          False           False
# 51289          False           False
#
# [51290 rows x 24 columns]

# %%
#checking total null values
print(df.isnull().sum())
print("------------------------")
print("Total             {}".format(df.isnull().sum().sum()))
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# City                  0
# State                 0
# Country               0
# Postal Code       41296
# Market                0
# Region                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64
# ------------------------
# Total             41296

# %%
sales_data = df.dropna(axis=1) #Drop the rows where all of the elements are nan (there is no row to drop, so df stays the same)

# %% [markdown]
# # **checking duplicate rows**

# %%
#checking if dataset has any duplicate rows
sales_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # **#converting the Dates in proper datetime format**

# %%
#converting the Dates in proper datetime format
sales_data['Order Date'] = pd.to_datetime(sales_data['Order Date'], errors = 'coerce')
sales_data['Ship Date'] = pd.to_datetime(sales_data['Ship Date'], errors = 'coerce')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51290 entries, 0 to 51289
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Market          51290 non-null  object
#  12  Region          51290 non-null  object
#  13  Product ID      51290 non-null  object
#  14  Category        51290 non-null  object
#  15  Sub-Category    51290 non-null  object
#  16  Product Name    51290 non-null  object
#  17  Sales           51290 non-null  float64
#  18  Quantity        51290 non-null  int64
#  19  Discount        51290 non-null  float64
#  20  Profit          51290 non-null  float64
#  21  Shipping Cost   51290 non-null  float64
#  22  Order Priority  51290 non-null  object
# dtypes: datetime64[ns](2), float64(4), int64(2), object(15)
# memory usage: 9.4+ MB

# %%
sales_data['Year'] = sales_data['Order Date'].dt.year #extracting the order year from orderdate column
sales_data['Month'] = sales_data['Order Date'].dt.month  #extracting the order month from orderdate column
sales_data['Day'] = sales_data['Order Date'].dt.day   #extracting the order day from orderdate column
sales_data["Month_year"] = sales_data['Order Date'].apply(lambda x: x.strftime('%Y-%m'))

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51290 entries, 0 to 51289
# Data columns (total 27 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Market          51290 non-null  object
#  12  Region          51290 non-null  object
#  13  Product ID      51290 non-null  object
#  14  Category        51290 non-null  object
#  15  Sub-Category    51290 non-null  object
#  16  Product Name    51290 non-null  object
#  17  Sales           51290 non-null  float64
#  18  Quantity        51290 non-null  int64
#  19  Discount        51290 non-null  float64
#  20  Profit          51290 non-null  float64
#  21  Shipping Cost   51290 non-null  float64
#  22  Order Priority  51290 non-null  object
#  23  Year            51290 non-null  int64
#  24  Month           51290 non-null  int64
#  25  Day             51290 non-null  int64
#  26  Month_year      51290 non-null  object
# dtypes: datetime64[ns](2), float64(4), int64(5), object(16)
# memory usage: 11.0+ MB

# %%
#exporting the cleaned data into a csv file so we can perform operations on that
sales_data.to_csv("GlobalSuperstore_Cleaned.csv")

# %%
sales_data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Market', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit',
#        'Shipping Cost', 'Order Priority', 'Year', 'Month', 'Day',
#        'Month_year'],
#       dtype='object')

# %% [markdown]
# # **EXPLORING DATASET**

# %%
sales_data["Country"].unique()
# Out:
# array(['Algeria', 'Australia', 'Hungary', 'Sweden', 'Canada',
#        'Philippines', 'Iraq', 'Tanzania', 'Iran', 'Thailand',
#        'New Zealand', 'Guatemala', 'United Kingdom', 'Malaysia', 'Cuba',
#        'Sudan', 'Japan', 'United States', 'Mexico', 'Brazil', 'France',
#        'Taiwan', 'China', 'Vietnam', 'Angola', 'Indonesia', 'Singapore',
#        'Lebanon', 'Netherlands', 'Mozambique', 'Nigeria', 'South Africa',
#        'Egypt', 'Venezuela', 'Italy', 'Spain', 'Austria', 'Turkey',
#        'India', 'Germany', 'Nicaragua', 'Dominican Republic', 'Denmark',
#        'El Salvador', 'Saudi Arabia', 'Zambia', 'Myanmar (Burma)',
#        'Russia', 'Mongolia', 'Belgium', 'Colombia', 'Kenya', 'Madagascar',
#        'Estonia', 'Norway', 'Morocco', 'Portugal', 'Sierra Leone',
#        'Central African Republic', 'Czech Republic', 'Benin', 'Panama',
#        'Bangladesh', 'Chile', 'South Korea', 'Moldova', 'Uganda',
#        'Switzerland', 'Zimbabwe', 'Hong Kong', 'Senegal', 'Niger',
#        'Democratic Republic of the Congo', 'Poland', 'Ireland',
#        'Pakistan', 'Azerbaijan', 'Ukraine', 'Israel', 'Honduras',
#        'Romania', 'Albania', 'Cameroon', 'Georgia', 'Cambodia',
#        'Argentina', 'Finland', 'Lithuania', 'Haiti', 'Peru', 'Somalia',
#        "Cote d'Ivoire", 'Afghanistan', 'Guinea', 'Liberia', 'South Sudan',
#        'Turkmenistan', 'Kazakhstan', 'Lesotho', 'Burundi', 'Qatar',
#        'Bulgaria', 'Martinique', 'Croatia', 'Ghana', 'Rwanda', 'Ecuador',
#        'Paraguay', 'Ethiopia', 'Syria', 'Tajikistan', 'Slovakia',
#        'Belarus', 'Papua New Guinea', 'Togo', 'Libya', 'Djibouti',
#        'Yemen', 'United Arab Emirates', 'Barbados', 'Uzbekistan',
#        'Jamaica', 'Bolivia', 'Uruguay', 'Republic of the Congo',
#        'Swaziland', 'Kyrgyzstan', 'Guinea-Bissau',
#        'Bosnia and Herzegovina', 'Tunisia', 'Armenia', 'Mali', 'Jordan',
#        'Trinidad and Tobago', 'Namibia', 'Gabon', 'Macedonia', 'Nepal',
#        'Mauritania', 'Guadeloupe', 'Sri Lanka', 'Chad', 'Eritrea',
#        'Bahrain', 'Equatorial Guinea', 'Slovenia', 'Montenegro'],
#       dtype=object)

# %%
print("Global Supermarket has a market spread over {} countries".format(sales_data["Country"].nunique()))
# Out:
# Global Supermarket has a market spread over 147 countries

# %%
sales_data["Category"].unique()
# Out:
# array(['Office Supplies', 'Furniture', 'Technology'], dtype=object)

# %%
sales_data["Sub-Category"].unique()
# Out:
# array(['Storage', 'Supplies', 'Paper', 'Furnishings', 'Machines',
#        'Fasteners', 'Envelopes', 'Art', 'Labels', 'Chairs', 'Accessories',
#        'Phones', 'Copiers', 'Appliances', 'Bookcases', 'Tables',
#        'Binders'], dtype=object)

# %%
plt.figure(figsize=(16,8))
plt.bar('Sub-Category','Category',data=sales_data,color='g')
plt.xticks(rotation=60)
plt.show()

# %%
plt.figure(figsize=(10,15))
sales_data['Sub-Category'].value_counts().plot.pie(autopct = "%1.1f%%")
plt.show()

# %%
group_by_sub_category = sales_data.groupby("Sub-Category")
group_by_sub_category.first() #getting first row of each subcategory
# Out:
#               Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# Sub-Category
# Accessories    30453    ID-2011-80230 2011-01-03 2011-01-09  Standard Class
# Appliances     20303    IN-2011-79397 2011-01-03 2011-01-03        Same Day
# Art            41807     IR-2011-7690 2011-01-03 2011-01-08    Second Class
# Binders        44302     SU-2011-5190 2011-01-04 2011-01-08  Standard Class
# Bookcases      16385  ES-2011-4869686 2011-01-03 2011-01-07  Standard Class
# Chairs         30452    ID-2011-80230 2011-01-03 2011-01-09  Standard Class
# Copiers        30450    ID-2011-80230 2011-01-03 2011-01-09  Standard Class
# Envelopes      46682     IZ-2011-4680 2011-01-03 2011-01-07  Standard Class
# Fasteners      26360    IN-2011-65159 2011-01-03 2011-01-07    Second Class
# Furnishings    22255    IN-2011-47883 2011-01-01 2011-01-08  Standard Class
# Labels         20302    IN-2011-79397 2011-01-03 2011-01-03        Same Day
# Machines       49550     CA-2011-1510 2011-01-02 2011-01-06  Standard Class
# Paper          11731  IT-2011-3647632 2011-01-01 2011-01-05    Second Class
# Phones          8187   MX-2011-160234 2011-01-03 2011-01-07  Standard Class
# Storage        42433     AG-2011-2040 2011-01-01 2011-01-06  Standard Class
# Supplies       22253    IN-2011-47883 2011-01-01 2011-01-08  Standard Class
# Tables         26361    IN-2011-65159 2011-01-03 2011-01-07    Second Class
#
#              Customer ID      Customer Name      Segment            City  \
# Sub-Category
# Accessories     KL-16645       Ken Lonsdale     Consumer        Papakura
# Appliances      KN-16450        Kean Nguyen    Corporate          Sydney
# Art              NG-8355         Nat Gilpin    Corporate         Mashhad
# Binders          JC-5340    Jasper Cacioppo     Consumer        Khartoum
# Bookcases       DD-13570  Dorothy Dickinson     Consumer       Southport
# Chairs          KL-16645       Ken Lonsdale     Consumer        Papakura
# Copiers         KL-16645       Ken Lonsdale     Consumer        Papakura
# Envelopes        LW-6990   Lindsay Williams    Corporate           Mosul
# Fasteners       LB-16735       Larry Blacks     Consumer          Manila
# Furnishings     JH-15985        Joseph Holt     Consumer     Wagga Wagga
# Labels          KN-16450        Kean Nguyen    Corporate          Sydney
# Machines         MM-7260    Magdelene Morse     Consumer  St. Catharines
# Paper           EM-14140       Eugene Moren  Home Office       Stockholm
# Phones          SV-20785   Stewart Visinsky     Consumer           Mixco
# Storage         TB-11280    Toby Braunhardt     Consumer     Constantine
# Supplies        JH-15985        Joseph Holt     Consumer     Wagga Wagga
# Tables          LB-16735       Larry Blacks     Consumer          Manila
#
#                          State  ...     Sales Quantity Discount    Profit  \
# Sub-Category                    ...
# Accessories           Auckland  ...   69.3000        2     0.40    3.4200
# Appliances     New South Wales  ...  276.1020        1     0.10  110.4120
# Art            Razavi Khorasan  ...   51.8400        1     0.00    7.7700
# Binders               Khartoum  ...    5.9100        1     0.00    2.1000
# Bookcases              England  ...  854.4900        7     0.00  290.4300
# Chairs                Auckland  ...   68.8680        2     0.40  -26.4120
# Copiers               Auckland  ...  912.4560        4     0.40 -319.4640
# Envelopes               Ninawa  ...   47.4300        1     0.00   17.0700
# Fasteners     National Capital  ...    6.0060        1     0.45    0.5460
# Furnishings    New South Wales  ...  113.6700        5     0.10   37.7700
# Labels         New South Wales  ...   35.8830        3     0.10    4.7430
# Machines               Ontario  ...  314.2200        1     0.00    3.1200
# Paper                Stockholm  ...   44.8650        3     0.50  -26.0550
# Phones               Guatemala  ...  195.2000        4     0.00   44.8800
# Storage            Constantine  ...  408.3000        2     0.00  106.1400
# Supplies       New South Wales  ...  120.3660        3     0.10   36.0360
# Tables        National Capital  ...  211.1805        1     0.55  -70.3995
#
#              Shipping Cost Order Priority  Year  Month  Day  Month_year
# Sub-Category
# Accessories          8.340            Low  2011      1    3     2011-01
# Appliances         125.320       Critical  2011      1    3     2011-01
# Art                  5.910           High  2011      1    3     2011-01
# Binders              0.510         Medium  2011      1    4     2011-01
# Bookcases           12.560         Medium  2011      1    3     2011-01
# Chairs               8.170            Low  2011      1    3     2011-01
# Copiers            107.100            Low  2011      1    3     2011-01
# Envelopes            3.570           High  2011      1    3     2011-01
# Fasteners            0.800           High  2011      1    3     2011-01
# Furnishings          4.700         Medium  2011      1    1     2011-01
# Labels               7.460       Critical  2011      1    3     2011-01
# Machines            24.100         Medium  2011      1    2     2011-01
# Paper                4.820           High  2011      1    1     2011-01
# Phones               8.431         Medium  2011      1    3     2011-01
# Storage             35.460         Medium  2011      1    1     2011-01
# Supplies             9.720         Medium  2011      1    1     2011-01
# Tables              21.320           High  2011      1    3     2011-01
#
# [17 rows x 26 columns]

# %%
profit = sales_data.groupby("Sub-Category")['Profit']
profit.first()
# Out:
# Sub-Category
# Accessories      3.4200
# Appliances     110.4120
# Art              7.7700
# Binders          2.1000
# Bookcases      290.4300
# Chairs         -26.4120
# Copiers       -319.4640
# Envelopes       17.0700
# Fasteners        0.5460
# Furnishings     37.7700
# Labels           4.7430
# Machines         3.1200
# Paper          -26.0550
# Phones          44.8800
# Storage        106.1400
# Supplies        36.0360
# Tables         -70.3995
# Name: Profit, dtype: float64

# %%
sales = sales_data.groupby("Sub-Category")['Sales']
sales.first()
# Out:
# Sub-Category
# Accessories     69.3000
# Appliances     276.1020
# Art             51.8400
# Binders          5.9100
# Bookcases      854.4900
# Chairs          68.8680
# Copiers        912.4560
# Envelopes       47.4300
# Fasteners        6.0060
# Furnishings    113.6700
# Labels          35.8830
# Machines       314.2200
# Paper           44.8650
# Phones         195.2000
# Storage        408.3000
# Supplies       120.3660
# Tables         211.1805
# Name: Sales, dtype: float64

# %%
sales = sales_data.groupby("Sub-Category")['Profit']
sales.first()
# Out:
# Sub-Category
# Accessories      3.4200
# Appliances     110.4120
# Art              7.7700
# Binders          2.1000
# Bookcases      290.4300
# Chairs         -26.4120
# Copiers       -319.4640
# Envelopes       17.0700
# Fasteners        0.5460
# Furnishings     37.7700
# Labels           4.7430
# Machines         3.1200
# Paper          -26.0550
# Phones          44.8800
# Storage        106.1400
# Supplies        36.0360
# Tables         -70.3995
# Name: Profit, dtype: float64

# %%
profit_sales = sales_data.groupby("Sub-Category")['Profit','Sales']
profit_sales.first()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                 Profit     Sales
# Sub-Category
# Accessories     3.4200   69.3000
# Appliances    110.4120  276.1020
# Art             7.7700   51.8400
# Binders         2.1000    5.9100
# Bookcases     290.4300  854.4900
# Chairs        -26.4120   68.8680
# Copiers      -319.4640  912.4560
# Envelopes      17.0700   47.4300
# Fasteners       0.5460    6.0060
# Furnishings    37.7700  113.6700
# Labels          4.7430   35.8830
# Machines        3.1200  314.2200
# Paper         -26.0550   44.8650
# Phones         44.8800  195.2000
# Storage       106.1400  408.3000
# Supplies       36.0360  120.3660
# Tables        -70.3995  211.1805

# %%
profit_sales = sales_data.groupby("Sub-Category")['Profit','Sales']
profit_sales.sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                     Profit         Sales
# Sub-Category
# Accessories   129626.30620  7.492370e+05
# Appliances    141680.58940  1.011064e+06
# Art            57953.91090  3.720920e+05
# Binders        72449.84600  4.619115e+05
# Bookcases     161924.41950  1.466572e+06
# Chairs        140396.26750  1.501682e+06
# Copiers       258567.54818  1.509436e+06
# Envelopes      29601.11630  1.709043e+05
# Fasteners      11525.42410  8.324232e+04
# Furnishings    46967.42550  3.855783e+05
# Labels         15010.51200  7.340403e+04
# Machines       58867.87300  7.790601e+05
# Paper          59207.68270  2.442917e+05
# Phones        216717.00580  1.706824e+06
# Storage       108461.48980  1.127086e+06
# Supplies       22583.26310  2.430742e+05
# Tables        -64083.38870  7.570419e+05

# %%
plt.figure(figsize=(10,15))
profit_sales.agg(['sum']).plot.bar()
plt.title('Total Profit and Sales per Sub-Category')
plt.show()

# %%
sales_data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Market', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit',
#        'Shipping Cost', 'Order Priority', 'Year', 'Month', 'Day',
#        'Month_year'],
#       dtype='object')

# %%
yearly_sale = sales_data.groupby('Year')['Sales']
yearly_sale.sum()
# Out:
# Year
# 2011    2.259451e+06
# 2012    2.677439e+06
# 2013    3.405746e+06
# 2014    4.299866e+06
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(12, 8))
yearly_sale.agg(['sum']).plot.bar()
plt.show()

# %%
yearly_profit = sales_data.groupby('Year')['Profit']
yearly_profit.sum()
# Out:
# Year
# 2011    248940.81154
# 2012    307415.27910
# 2013    406935.23018
# 2014    504165.97046
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(12, 8))
yearly_profit.agg(['sum']).plot.bar()
plt.show()

# %%
sales_data['Product Name'].nunique()
# Out:
# 3788

# %% [markdown]
# # **ANALYSIS BASED ON THE CATEGORY OF PRODUCTS**

# %%
data = sales_data.copy()

# %% [markdown]
# # ***# GRAPH OF SALES vs PROIT BASED ON EACH *SUBCATEGORY* OF PRODUCT ***

# %%
group_by_sub_category = data.groupby("Sub-Category")

# %%
#PROFIT
profit = data.groupby("Sub-Category")['Profit']
profit.first()
# Out:
# Sub-Category
# Accessories      3.4200
# Appliances     110.4120
# Art              7.7700
# Binders          2.1000
# Bookcases      290.4300
# Chairs         -26.4120
# Copiers       -319.4640
# Envelopes       17.0700
# Fasteners        0.5460
# Furnishings     37.7700
# Labels           4.7430
# Machines         3.1200
# Paper          -26.0550
# Phones          44.8800
# Storage        106.1400
# Supplies        36.0360
# Tables         -70.3995
# Name: Profit, dtype: float64

# %%
#SALES
sales = data.groupby("Sub-Category")['Sales']
sales.first()
# Out:
# Sub-Category
# Accessories     69.3000
# Appliances     276.1020
# Art             51.8400
# Binders          5.9100
# Bookcases      854.4900
# Chairs          68.8680
# Copiers        912.4560
# Envelopes       47.4300
# Fasteners        6.0060
# Furnishings    113.6700
# Labels          35.8830
# Machines       314.2200
# Paper           44.8650
# Phones         195.2000
# Storage        408.3000
# Supplies       120.3660
# Tables         211.1805
# Name: Sales, dtype: float64

# %%
profit_sales = data.groupby("Sub-Category")['Profit','Sales']
profit_sales.first()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                 Profit     Sales
# Sub-Category
# Accessories     3.4200   69.3000
# Appliances    110.4120  276.1020
# Art             7.7700   51.8400
# Binders         2.1000    5.9100
# Bookcases     290.4300  854.4900
# Chairs        -26.4120   68.8680
# Copiers      -319.4640  912.4560
# Envelopes      17.0700   47.4300
# Fasteners       0.5460    6.0060
# Furnishings    37.7700  113.6700
# Labels          4.7430   35.8830
# Machines        3.1200  314.2200
# Paper         -26.0550   44.8650
# Phones         44.8800  195.2000
# Storage       106.1400  408.3000
# Supplies       36.0360  120.3660
# Tables        -70.3995  211.1805

# %%
profit_sales = data.groupby("Sub-Category")['Profit','Sales']
profit_sales.sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                     Profit         Sales
# Sub-Category
# Accessories   129626.30620  7.492370e+05
# Appliances    141680.58940  1.011064e+06
# Art            57953.91090  3.720920e+05
# Binders        72449.84600  4.619115e+05
# Bookcases     161924.41950  1.466572e+06
# Chairs        140396.26750  1.501682e+06
# Copiers       258567.54818  1.509436e+06
# Envelopes      29601.11630  1.709043e+05
# Fasteners      11525.42410  8.324232e+04
# Furnishings    46967.42550  3.855783e+05
# Labels         15010.51200  7.340403e+04
# Machines       58867.87300  7.790601e+05
# Paper          59207.68270  2.442917e+05
# Phones        216717.00580  1.706824e+06
# Storage       108461.48980  1.127086e+06
# Supplies       22583.26310  2.430742e+05
# Tables        -64083.38870  7.570419e+05

# %%
plt.figure(figsize=(15,8))
profit_sales.agg(['sum']).plot.bar()
plt.title('Total Profit and Sales per Sub-Category')
plt.ylabel('Sales/Profit')
plt.show()

# %%
profit_sales_year = data.groupby(["Sub-Category",'Year'])['Profit','Sales']
profit_sales_year.sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                        Profit        Sales
# Sub-Category Year
# Accessories  2011  15719.8606  113456.0076
#              2012  33507.1002  172397.6850
#              2013  38805.4168  209895.1623
#              2014  41593.9286  253488.1636
# Appliances   2011  22838.4413  173383.4264
# ...                       ...          ...
# Supplies     2014   7365.4090   86283.0918
# Tables       2011 -11075.2945  147131.4937
#              2012  -8421.6986  164086.4968
#              2013 -14040.4872  202363.5351
#              2014 -30545.9084  243460.3988
#
# [68 rows x 2 columns]

# %% [markdown]
# # **# FINDING WHCH SUBCATEGORY OF PRODUCT IS POPULAR CITY WISE**

# %%
popular_subcategory = data[['Sub-Category', 'City', 'Quantity']].groupby(['Sub-Category', 'City', 'Quantity']).sum()
popular_subcategory
# Out:
# Empty DataFrame
# Columns: []
# Index: [(Accessories, Abadan, 2), (Accessories, Abidjan, 1), (Accessories, Abidjan, 2), (Accessories, Abu Kabir, 1), (Accessories, Accra, 2), (Accessories, Accra, 10), (Accessories, Acerra, 5), (Accessories, Acuña, 5), (Accessories, Adana, 1), (Accessories, Adelaide, 2), (Accessories, Adelaide, 3), (Accessories, Adelaide, 4), (Accessories, Adelaide, 5), (Accessories, Adelaide, 6), (Accessories, Adelaide, 9), (Accessories, Agadir, 1), (Accessories, Agra, 2), (Accessories, Agra, 4), (Accessories, Agra, 9), (Accessories, Ahvaz, 1), (Accessories, Aix-en-Provence, 1), (Accessories, Ajmer, 2), (Accessories, Akhisar, 1), (Accessories, Akron, 3), (Accessories, Akron, 5), (Accessories, Al Hillah, 2), (Accessories, Al Hufuf, 4), (Accessories, Al Mubarraz, 1), (Accessories, Alanya, 1), (Accessories, Albacete, 3), (Accessories, Albany, 3), (Accessories, Albuquerque, 5), (Accessories, Albury, 1), (Accessories, Albury, 4), (Accessories, Albury, 8), (Accessories, Alexandria, 1), (Accessories, Alexandria, 4), (Accessories, Alexandria, 8), (Accessories, Algiers, 1), (Accessories, Allahabad, 1), (Accessories, Allen, 3), (Accessories, Allentown, 4), (Accessories, Altamura, 7), (Accessories, Amadora, 9), (Accessories, Amarillo, 3), (Accessories, Amersfoort, 3), (Accessories, Amman, 4), (Accessories, Amritsar, 6), (Accessories, Amsterdam, 2), (Accessories, Amsterdam, 3), (Accessories, Amsterdam, 8), (Accessories, An Nasiriyah, 1), (Accessories, Anaheim, 4), (Accessories, Angarsk, 1), (Accessories, Angers, 5), (Accessories, Ankara, 1), (Accessories, Ankara, 2), (Accessories, Ankara, 4), (Accessories, Ankara, 6), (Accessories, Ann Arbor, 5), (Accessories, Annaba, 1), (Accessories, Annaba, 4), (Accessories, Annecy, 7), (Accessories, Annemasse, 5), (Accessories, Anshan, 5), (Accessories, Antakya, 6), (Accessories, Antalya, 1), (Accessories, Antananarivo, 2), (Accessories, Antipolo, 3), (Accessories, Antipolo, 4), (Accessories, Antofagasta, 4), (Accessories, Antony, 5), (Accessories, Antwerp, 3), (Accessories, Antwerp, 4), (Accessories, Anyang, 3), (Accessories, Aoba-ku, 1), (Accessories, Apeldoorn, 2), (Accessories, Apodaca, 3), (Accessories, Apopa, 3), (Accessories, Apopa, 5), (Accessories, Apopa, 6), (Accessories, Apopa, 9), (Accessories, Appleton, 5), (Accessories, Aracaju, 2), (Accessories, Araguaína, 2), (Accessories, Arak, 1), (Accessories, Araranguá, 2), (Accessories, Arbil, 1), (Accessories, Arcoverde, 3), (Accessories, Ardabil, 1), (Accessories, Ardabil, 2), (Accessories, Ardabil, 4), (Accessories, Arica, 7), (Accessories, Arles, 2), (Accessories, Arlington, 2), (Accessories, Arlington, 3), (Accessories, Armidale, 7), (Accessories, Arraiján, 1), (Accessories, Arraiján, 2), (Accessories, Arraiján, 4), ...]
#
# [36481 rows x 0 columns]

# %%
data.groupby(["Sub-Category","City"])['City'].count().sort_values().groupby(level=0).tail(1)
# Out:
# Sub-Category  City
# Machines      Manila            20
# Envelopes     Tegucigalpa       26
# Copiers       Manila            27
# Bookcases     Managua           31
# Tables        Los Angeles       32
# Supplies      Santo Domingo     32
# Fasteners     Santo Domingo     35
# Labels        New York City     36
# Appliances    Los Angeles       37
# Chairs        New York City     62
# Accessories   New York City     64
# Art           New York City     70
# Furnishings   New York City     78
# Storage       New York City     82
# Phones        New York City     89
# Paper         New York City    124
# Binders       New York City    145
# Name: City, dtype: int64

# %% [markdown]
# # **## FINDING WHICH SUBCATEGORY OF THE PRODUCT IS GIVING HIGHEST PROFIT**

# %%
highest_category_profit = data.groupby(by=['Category']).sum().sort_values(by=['Profit']).reset_index()
highest_category_profit
# Out:
#           Category     Row ID         Sales  Quantity  Discount        Profit  \
# 0        Furniture  241487920  4.110874e+06     34954  1660.030  285204.72380
# 1  Office Supplies  815386724  3.787070e+06    108182  4297.190  518473.83430
# 2       Technology  258483051  4.744557e+06     35176  1372.508  663778.73318
#
#    Shipping Cost      Year   Month     Day
# 0    440319.4790  19878166   74968  156524
# 1    405448.3450  62945679  234497  494357
# 2    507047.8794  20411498   76371  158627

# %%
plt.figure(figsize=(12,8))
plt.bar("Category",'Profit',data=highest_category_profit)
plt.show()

# %%
highest_subcategory_profit = data[['Sub-Category', 'Profit']].groupby(['Sub-Category']).sum().reset_index()
plt.figure(figsize=(16, 8))
plt.bar('Sub-Category', 'Profit', data = highest_subcategory_profit)
plt.xticks(rotation='vertical', size=12)
plt.show()

# %%
df['Order Date'].min()
# Out:
# '2011-01-01'

# %%
df['Order Date'].max()
# Out:
# '2014-12-31'

# %%
df1 = df.groupby('Order Date').sum()['Profit'].reset_index()
df1
# Out:
#       Order Date      Profit
# 0     2011-01-01   198.87300
# 1     2011-01-02     3.12000
# 2     2011-01-03   184.59720
# 3     2011-01-04   635.12344
# 4     2011-01-05  1053.36990
# ...          ...         ...
# 1425  2014-12-27  -916.64004
# 1426  2014-12-28    81.06380
# 1427  2014-12-29  2046.20678
# 1428  2014-12-30  2554.00460
# 1429  2014-12-31  1020.17080
#
# [1430 rows x 2 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1430 entries, 0 to 1429
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Order Date  1430 non-null   object
#  1   Profit      1430 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 22.5+ KB

# %%
#converting the date column into standard datetime pattern

import datetime as dt
df1['Order Date'] = pd.to_datetime(df1['Order Date'], errors = 'coerce')
df1 = df1[df1['Order Date'].dt.year == 2011]
df1
# Out:
#     Order Date      Profit
# 0   2011-01-01   198.87300
# 1   2011-01-02     3.12000
# 2   2011-01-03   184.59720
# 3   2011-01-04   635.12344
# 4   2011-01-05  1053.36990
# ..         ...         ...
# 346 2011-12-27  1130.14960
# 347 2011-12-28   313.83412
# 348 2011-12-29  1813.20640
# 349 2011-12-30   858.59640
# 350 2011-12-31  1777.24610
#
# [351 rows x 2 columns]

# %%
#Profit trend for the year 2011
plt.figure(figsize=(12, 8))
plt.plot(df1['Order Date'], df1['Profit'])
plt.xticks(rotation='vertical')
plt.show()
